# %%
import os 
import sys 

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from IPython.display import clear_output 
from six.moves import urllib

# %%
import tensorflow.compat.v2.feature_column as fc 
import tensorflow as tf

# %%
dftrain = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
dfeval = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv')

# %%
dftrain.head()
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0         0    male  22.0                   1      0   7.2500  Third  unknown
# 1         1  female  38.0                   1      0  71.2833  First        C
# 2         1  female  26.0                   0      0   7.9250  Third  unknown
# 3         1  female  35.0                   1      0  53.1000  First        C
# 4         0    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
dfeval.head()
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0         0    male  35.0                   0      0   8.0500   Third
# 1         0    male  54.0                   0      0  51.8625   First
# 2         1  female  58.0                   0      0  26.5500   First
# 3         1  female  55.0                   0      0  16.0000  Second
# 4         1    male  34.0                   0      0  13.0000  Second
#
#       deck  embark_town alone
# 0  unknown  Southampton     y
# 1        E  Southampton     y
# 2        C  Southampton     y
# 3  unknown  Southampton     y
# 4        D  Southampton     y

# %%
y_train = dftrain.pop('survived')

# %%
y_eval = dfeval.pop('survived')

# %%
dftrain.describe()
# Out:
#               age  n_siblings_spouses       parch        fare
# count  627.000000          627.000000  627.000000  627.000000
# mean    29.631308            0.545455    0.379585   34.385399
# std     12.511818            1.151090    0.792999   54.597730
# min      0.750000            0.000000    0.000000    0.000000
# 25%     23.000000            0.000000    0.000000    7.895800
# 50%     28.000000            0.000000    0.000000   15.045800
# 75%     35.000000            1.000000    0.000000   31.387500
# max     80.000000            8.000000    5.000000  512.329200

# %%
dftrain.shape , dfeval.shape
# Out:
# ((627, 9), (264, 9))

# %%
dftrain.age.hist(bins=20)

# %%
dftrain.hist(bins=20, figsize=(10, 5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9465cc12e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9465cbc908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f94653dfa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94653dbba8>]],
#       dtype=object)

# %%
dftrain.sex.value_counts()
# Out:
# male      410
# female    217
# Name: sex, dtype: int64

# %%
dftrain.sex.value_counts().plot(kind='barh')

# %%
a = pd.concat([dftrain, y_train], axis=1)
a
# Out:
#         sex   age  n_siblings_spouses  parch     fare   class     deck  \
# 0      male  22.0                   1      0   7.2500   Third  unknown
# 1    female  38.0                   1      0  71.2833   First        C
# 2    female  26.0                   0      0   7.9250   Third  unknown
# 3    female  35.0                   1      0  53.1000   First        C
# 4      male  28.0                   0      0   8.4583   Third  unknown
# ..      ...   ...                 ...    ...      ...     ...      ...
# 622    male  28.0                   0      0  10.5000  Second  unknown
# 623    male  25.0                   0      0   7.0500   Third  unknown
# 624  female  19.0                   0      0  30.0000   First        B
# 625  female  28.0                   1      2  23.4500   Third  unknown
# 626    male  32.0                   0      0   7.7500   Third  unknown
#
#      embark_town alone  survived
# 0    Southampton     n         0
# 1      Cherbourg     n         1
# 2    Southampton     y         1
# 3    Southampton     n         1
# 4     Queenstown     y         0
# ..           ...   ...       ...
# 622  Southampton     y         0
# 623  Southampton     y         0
# 624  Southampton     y         1
# 625  Southampton     n         0
# 626   Queenstown     y         0
#
# [627 rows x 10 columns]

# %%
dftrain.head()
# Out:
#       sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0    male  22.0                   1      0   7.2500  Third  unknown
# 1  female  38.0                   1      0  71.2833  First        C
# 2  female  26.0                   0      0   7.9250  Third  unknown
# 3  female  35.0                   1      0  53.1000  First        C
# 4    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
a.groupby('sex')

# %%
a
# Out:
#         sex   age  n_siblings_spouses  parch     fare   class     deck  \
# 0      male  22.0                   1      0   7.2500   Third  unknown
# 1    female  38.0                   1      0  71.2833   First        C
# 2    female  26.0                   0      0   7.9250   Third  unknown
# 3    female  35.0                   1      0  53.1000   First        C
# 4      male  28.0                   0      0   8.4583   Third  unknown
# ..      ...   ...                 ...    ...      ...     ...      ...
# 622    male  28.0                   0      0  10.5000  Second  unknown
# 623    male  25.0                   0      0   7.0500   Third  unknown
# 624  female  19.0                   0      0  30.0000   First        B
# 625  female  28.0                   1      2  23.4500   Third  unknown
# 626    male  32.0                   0      0   7.7500   Third  unknown
#
#      embark_town alone  survived
# 0    Southampton     n         0
# 1      Cherbourg     n         1
# 2    Southampton     y         1
# 3    Southampton     n         1
# 4     Queenstown     y         0
# ..           ...   ...       ...
# 622  Southampton     y         0
# 623  Southampton     y         0
# 624  Southampton     y         1
# 625  Southampton     n         0
# 626   Queenstown     y         0
#
# [627 rows x 10 columns]

# %%
a.groupby('sex').survived.mean()
# Out:
# sex
# female    0.778802
# male      0.180488
# Name: survived, dtype: float64

# %%
a.groupby('sex').size()
# Out:
# sex
# female    217
# male      410
# dtype: int64

# %%
CATEGORICAL_COLUMNS = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck',
                       'embark_town', 'alone']
NUMERIC_COLUMNS = ['age', 'fare']

# %%
feature_columns = []
for feature_name in CATEGORICAL_COLUMNS:
    vocabulary = dftrain[feature_name].unique()
    feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))
    print(vocabulary)
# Out:
# ['male' 'female']
# [1 0 3 4 2 5 8]
# [0 1 2 5 3 4]
# ['Third' 'First' 'Second']
# ['unknown' 'C' 'G' 'A' 'B' 'D' 'F' 'E']
# ['Southampton' 'Cherbourg' 'Queenstown' 'unknown']
# ['n' 'y']

# %%
feature_columns
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0)]

# %%
for feature_name in NUMERIC_COLUMNS:
    feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

# %%
feature_columns
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='fare', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=32):
    def input_function():
        ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))
        if shuffle:
            ds = ds.shuffle(1000)
        ds = ds.batch(batch_size).repeat(num_epochs)
        return ds 
    return input_function

# %%
train_input_fn = make_input_fn(dftrain, y_train)

# %%
train_input_fn
# Out:
# <function __main__.make_input_fn.<locals>.input_function()>

# %%
eval_input_fn = make_input_fn(dfeval, y_eval, num_epochs=1, shuffle=False)

# %%
ds = make_input_fn(dftrain, y_train, batch_size=10)()

# %%
ds
# Out:
# <RepeatDataset shapes: ({sex: (None,), age: (None,), n_siblings_spouses: (None,), parch: (None,), fare: (None,), class: (None,), deck: (None,), embark_town: (None,), alone: (None,)}, (None,)), types: ({sex: tf.string, age: tf.float64, n_siblings_spouses: tf.int32, parch: tf.int32, fare: tf.float64, class: tf.string, deck: tf.string, embark_town: tf.string, alone: tf.string}, tf.int32)>

# %%
for feature_batch , label_batch in ds.take(1):
    print(list(feature_batch))
    # print()
    print(list(feature_batch.keys()))
    print(feature_batch['class'].numpy())
# Out:
# ['sex', 'age', 'n_siblings_spouses', 'parch', 'fare', 'class', 'deck', 'embark_town', 'alone']
# ['sex', 'age', 'n_siblings_spouses', 'parch', 'fare', 'class', 'deck', 'embark_town', 'alone']
# [b'First' b'Third' b'Third' b'Third' b'Third' b'Third' b'First' b'Second'
#  b'Third' b'Third']

# %%
feature_columns
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='fare', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
linear_set = tf.estimator.LinearClassifier(feature_columns=feature_columns)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpnhn6yycv
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpnhn6yycv', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
train_input_fn
# Out:
# <function __main__.make_input_fn.<locals>.input_function()>

# %%
linear_set.train(train_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:From /home/mark/.pyenv/versions/anaconda3-5.0.0/envs/tf2/lib/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:518: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /home/mark/.pyenv/versions/anaconda3-5.0.0/envs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/optimizer_v2/ftrl.py:143: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpnhn6yycv/model.ckpt.
# INFO:tensorflow:loss = 0.6931472, step = 0
# INFO:tensorflow:global_step/sec: 370.538
# INFO:tensorflow:loss = 0.4458738, step = 100 (0.270 sec)
# INFO:tensorflow:Saving checkpoints for 200 into /tmp/tmpnhn6yycv/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.41384038.

# %%
result = linear_set.evaluate(eval_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-02-25T19:33:14Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpnhn6yycv/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.58336s
# INFO:tensorflow:Finished evaluation at 2020-02-25-19:33:15
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.75757575, accuracy_baseline = 0.625, auc = 0.83731246, auc_precision_recall = 0.78283036, average_loss = 0.47513276, global_step = 200, label/mean = 0.375, loss = 0.46559873, precision = 0.68817204, prediction/mean = 0.34489408, recall = 0.64646465
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: /tmp/tmpnhn6yycv/model.ckpt-200

# %%
result
# Out:
# {'accuracy': 0.75757575,
#  'accuracy_baseline': 0.625,
#  'auc': 0.83731246,
#  'auc_precision_recall': 0.78283036,
#  'average_loss': 0.47513276,
#  'label/mean': 0.375,
#  'loss': 0.46559873,
#  'precision': 0.68817204,
#  'prediction/mean': 0.34489408,
#  'recall': 0.64646465,
#  'global_step': 200}

# %%
age_x_gender = tf.feature_column.crossed_column(['age', 'sex'], hash_bucket_size=100)

# %%
print(age_x_gender)
# Out:
# CrossedColumn(keys=('age', 'sex'), hash_bucket_size=100, hash_key=None)

# %%
derived_feature_columns = [age_x_gender]
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns+derived_feature_columns)
linear_est.train(train_input_fn)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp7jv0pybb
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp7jv0pybb', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp7jv0pybb/model.ckpt.
# INFO:tensorflow:loss = 0.6931472, step = 0
# INFO:tensorflow:global_step/sec: 351.892
# INFO:tensorflow:loss = 0.36196128, step = 100 (0.285 sec)
# INFO:tensorflow:Saving checkpoints for 200 into /tmp/tmp7jv0pybb/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.35734147.

# %%
result = linear_est.evaluate(eval_input_fn)
result
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-02-25T21:57:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp7jv0pybb/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.57905s
# INFO:tensorflow:Finished evaluation at 2020-02-25-21:57:09
# INFO:tensorflow:Saving dict for global step 200: accuracy = 0.75757575, accuracy_baseline = 0.625, auc = 0.838292, auc_precision_recall = 0.7834264, average_loss = 0.50942445, global_step = 200, label/mean = 0.375, loss = 0.50465703, precision = 0.64705884, prediction/mean = 0.47769418, recall = 0.7777778
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: /tmp/tmp7jv0pybb/model.ckpt-200
# {'accuracy': 0.75757575,
#  'accuracy_baseline': 0.625,
#  'auc': 0.838292,
#  'auc_precision_recall': 0.7834264,
#  'average_loss': 0.50942445,
#  'label/mean': 0.375,
#  'loss': 0.50465703,
#  'precision': 0.64705884,
#  'prediction/mean': 0.47769418,
#  'recall': 0.7777778,
#  'global_step': 200}

# %%
result
# Out:
# {'accuracy': 0.75757575,
#  'accuracy_baseline': 0.625,
#  'auc': 0.838292,
#  'auc_precision_recall': 0.7834264,
#  'average_loss': 0.50942445,
#  'label/mean': 0.375,
#  'loss': 0.50465703,
#  'precision': 0.64705884,
#  'prediction/mean': 0.47769418,
#  'recall': 0.7777778,
#  'global_step': 200}

# %%
pred_dicts = list(linear_est.predict(eval_input_fn))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp7jv0pybb/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
pred_dicts
# Out:
#  dtype=object)},
#  {'logits': array([6.2054653], dtype=float32),
#   'logistic': array([0.9979857], dtype=float32),
#   'probabilities': array([0.0020143, 0.9979857], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.8661388], dtype=float32),
#   'logistic': array([0.86601084], dtype=float32),
#   'probabilities': array([0.13398913, 0.86601084], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5427337], dtype=float32),
#   'logistic': array([0.17613824], dtype=float32),
#   'probabilities': array([0.8238617 , 0.17613822], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5925397], dtype=float32),
#   'logistic': array([0.83097315], dtype=float32),
#   'probabilities': array([0.16902688, 0.83097315], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5106424], dtype=float32),
#   'logistic': array([0.6249571], dtype=float32),
#   'probabilities': array([0.37504295, 0.6249571 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.99358404], dtype=float32),
#   'logistic': array([0.27020475], dtype=float32),
#   'probabilities': array([0.7297952 , 0.27020472], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6763178], dtype=float32),
#   'logistic': array([0.15758367], dtype=float32),
#   'probabilities': array([0.8424163 , 0.15758365], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0234765], dtype=float32),
#   'logistic': array([0.26435077], dtype=float32),
#   'probabilities': array([0.7356492, 0.2643508], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3252157], dtype=float32),
#   'logistic': array([0.20995186], dtype=float32),
#   'probabilities': array([0.7900481 , 0.20995185], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2380469], dtype=float32),
#   'logistic': array([0.77522385], dtype=float32),
#   'probabilities': array([0.22477615, 0.77522385], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0419343], dtype=float32),
#   'logistic': array([0.11486991], dtype=float32),
#   'probabilities': array([0.8851301 , 0.11486992], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0824664], dtype=float32),
#   'logistic': array([0.74696046], dtype=float32),
#   'probabilities': array([0.25303957, 0.74696046], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.1965101], dtype=float32),
#   'logistic': array([0.45102996], dtype=float32),
#   'probabilities': array([0.54897004, 0.45102996], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7113518], dtype=float32),
#   'logistic': array([0.15298846], dtype=float32),
#   'probabilities': array([0.8470115 , 0.15298846], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3487433], dtype=float32),
#   'logistic': array([0.2060759], dtype=float32),
#   'probabilities': array([0.79392403, 0.20607588], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2102337], dtype=float32),
#   'logistic': array([0.77034026], dtype=float32),
#   'probabilities': array([0.22965969, 0.77034026], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4801748], dtype=float32),
#   'logistic': array([0.61778915], dtype=float32),
#   'probabilities': array([0.38221085, 0.61778915], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4488353], dtype=float32),
#   'logistic': array([0.19018088], dtype=float32),
#   'probabilities': array([0.80981916, 0.1901809 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.19472864], dtype=float32),
#   'logistic': array([0.45147112], dtype=float32),
#   'probabilities': array([0.5485289, 0.4514711], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1763698], dtype=float32),
#   'logistic': array([0.23570555], dtype=float32),
#   'probabilities': array([0.76429445, 0.23570554], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.8005433], dtype=float32),
#   'logistic': array([0.97813034], dtype=float32),
#   'probabilities': array([0.02186965, 0.97813034], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.8909578], dtype=float32),
#   'logistic': array([0.9799831], dtype=float32),
#   'probabilities': array([0.02001691, 0.9799831 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5713071], dtype=float32),
#   'logistic': array([0.17203014], dtype=float32),
#   'probabilities': array([0.82796985, 0.17203014], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.61619544], dtype=float32),
#   'logistic': array([0.6493528], dtype=float32),
#   'probabilities': array([0.35064724, 0.6493528 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9442261], dtype=float32),
#   'logistic': array([0.1251843], dtype=float32),
#   'probabilities': array([0.8748157 , 0.12518431], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5646622], dtype=float32),
#   'logistic': array([0.17297867], dtype=float32),
#   'probabilities': array([0.8270213 , 0.17297867], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.4674308], dtype=float32),
#   'logistic': array([0.8126666], dtype=float32),
#   'probabilities': array([0.18733343, 0.8126666 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8900715], dtype=float32),
#   'logistic': array([0.13123631], dtype=float32),
#   'probabilities': array([0.8687636, 0.1312363], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([5.6554356], dtype=float32),
#   'logistic': array([0.9965138], dtype=float32),
#   'probabilities': array([0.00348625, 0.9965138 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5846672], dtype=float32),
#   'logistic': array([0.8298645], dtype=float32),
#   'probabilities': array([0.17013551, 0.8298645 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3403864], dtype=float32),
#   'logistic': array([0.20744653], dtype=float32),
#   'probabilities': array([0.7925535 , 0.20744652], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3103615], dtype=float32),
#   'logistic': array([0.7875737], dtype=float32),
#   'probabilities': array([0.21242636, 0.7875737 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5052168], dtype=float32),
#   'logistic': array([0.18164875], dtype=float32),
#   'probabilities': array([0.81835127, 0.18164875], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6404679], dtype=float32),
#   'logistic': array([0.34514078], dtype=float32),
#   'probabilities': array([0.65485924, 0.3451408 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3825022], dtype=float32),
#   'logistic': array([0.20060742], dtype=float32),
#   'probabilities': array([0.7993926 , 0.20060743], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3143882], dtype=float32),
#   'logistic': array([0.7882466], dtype=float32),
#   'probabilities': array([0.21175349, 0.7882466 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2390841], dtype=float32),
#   'logistic': array([0.5594879], dtype=float32),
#   'probabilities': array([0.44051206, 0.5594879 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9703866], dtype=float32),
#   'logistic': array([0.12234736], dtype=float32),
#   'probabilities': array([0.8776526 , 0.12234736], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8587953], dtype=float32),
#   'logistic': array([0.2975911], dtype=float32),
#   'probabilities': array([0.7024089 , 0.29759112], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.8253325], dtype=float32),
#   'logistic': array([0.86120474], dtype=float32),
#   'probabilities': array([0.13879524, 0.86120474], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.27928418], dtype=float32),
#   'logistic': array([0.5693707], dtype=float32),
#   'probabilities': array([0.43062925, 0.5693707 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.331893], dtype=float32),
#   'logistic': array([0.9655069], dtype=float32),
#   'probabilities': array([0.03449313, 0.9655069 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.13581148], dtype=float32),
#   'logistic': array([0.46609923], dtype=float32),
#   'probabilities': array([0.5339008 , 0.46609923], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7752181], dtype=float32),
#   'logistic': array([0.3153514], dtype=float32),
#   'probabilities': array([0.68464863, 0.31535143], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3358518], dtype=float32),
#   'logistic': array([0.20819306], dtype=float32),
#   'probabilities': array([0.79180694, 0.20819306], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6272863], dtype=float32),
#   'logistic': array([0.16420245], dtype=float32),
#   'probabilities': array([0.83579755, 0.16420245], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.3369935], dtype=float32),
#   'logistic': array([0.08810517], dtype=float32),
#   'probabilities': array([0.9118948 , 0.08810516], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.6510204], dtype=float32),
#   'logistic': array([0.83902895], dtype=float32),
#   'probabilities': array([0.1609711 , 0.83902895], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.8872776], dtype=float32),
#   'logistic': array([0.8684448], dtype=float32),
#   'probabilities': array([0.1315552, 0.8684448], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5646015], dtype=float32),
#   'logistic': array([0.17298736], dtype=float32),
#   'probabilities': array([0.82701266, 0.17298734], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.94896257], dtype=float32),
#   'logistic': array([0.2790935], dtype=float32),
#   'probabilities': array([0.7209065, 0.2790935], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.6935792], dtype=float32),
#   'logistic': array([0.9366467], dtype=float32),
#   'probabilities': array([0.06335329, 0.9366467 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7633749], dtype=float32),
#   'logistic': array([0.68208605], dtype=float32),
#   'probabilities': array([0.31791398, 0.68208605], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1296928], dtype=float32),
#   'logistic': array([0.10624416], dtype=float32),
#   'probabilities': array([0.8937558 , 0.10624415], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.0644763], dtype=float32),
#   'logistic': array([0.9554034], dtype=float32),
#   'probabilities': array([0.04459659, 0.9554034 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.8304516], dtype=float32),
#   'logistic': array([0.8618155], dtype=float32),
#   'probabilities': array([0.13818449, 0.8618155 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8915832], dtype=float32),
#   'logistic': array([0.13106406], dtype=float32),
#   'probabilities': array([0.868936  , 0.13106407], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6989318], dtype=float32),
#   'logistic': array([0.66795087], dtype=float32),
#   'probabilities': array([0.33204907, 0.66795087], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5196736], dtype=float32),
#   'logistic': array([0.37292856], dtype=float32),
#   'probabilities': array([0.62707144, 0.37292856], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.55015457], dtype=float32),
#   'logistic': array([0.6341714], dtype=float32),
#   'probabilities': array([0.36582854, 0.6341714 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %%
len(pred_dicts)
# Out:
# 264

# %%
probs = pd.Series([pred['probabilities'][1] for pred in pred_dicts])

# %%
probs
# Out:
# 0      0.169001
# 1      0.670645
# 2      0.872151
# 3      0.815879
# 4      0.376239
#          ...
# 259    0.861816
# 260    0.131064
# 261    0.667951
# 262    0.372929
# 263    0.634171
# Length: 264, dtype: float64

# %%
probs.plot(kind='hist', bins=20, title='predicted probilities')
